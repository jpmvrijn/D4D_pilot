# %%
import  matplotlib  as mpl
import matplotlib.pyplot as plt

import networkx as nx
import numpy as np
import pandas as pd
import pickle

from visJS2jupyter import visJS_module

# %%
df = pd.read_pickle("/Users/Jeaphianne/Documents/Work/DSP/df_for_visualization")

# %%
with open("/Users/Jeaphianne/Documents/Work/DSP/color_dict", "rb") as file:
    color_dict = pickle.load(file)

# %%
G = nx.from_pandas_edgelist(df, 'provider_name', 'receiver_name', edge_attr=True)

# %%
nodes = list(G.nodes())
edges = list(G.edges())

# %%
# 1=ug=donker blauw
# 2=nl=oranje
# 3=gb=roze
# 4=us=rood
# 5=UNK=groen
# 6=other=geel

# %%
pos = nx.spring_layout(G)

nodes_dict = [{"id":n,"color":color_dict[n],
              "x":pos[n][0]*1000,
              "y":pos[n][1]*1000} for n in nodes
              ]
node_map = dict(zip(nodes,range(len(nodes))))  # map to indices for source/target in edges
edges_dict = [{"source":node_map[edges[i][0]], "target":node_map[edges[i][1]], 
              "color":"gray","title":'test'} for i in range(len(edges))]

visJS_module.visjs_network(nodes_dict,edges_dict,time_stamp=1,
                          node_size_multiplier=7,
                          node_size_transform = '',
                          node_color_highlight_border='red',
                          node_color_highlight_background='#D3918B',
                          node_color_hover_border='#9aaaba',
                          node_color_hover_background='#8BADD3',
                          node_font_size=25,
                          edge_arrow_to=True,
                          physics_enabled=True,
                          edge_color_highlight='#8A324E',
                          edge_color_hover='#9aaaba',
                          edge_width=3,
                          max_velocity=15,
                          min_velocity=1,
                          graph_title ='ug=donker blauw, nl=oranje, gb=roze, us=rood, unknown=groen, other=geel')
# Out:
# <!doctype html><html><head>  <title>Network | Basic usage</title></head><body><script type="text/javascript">function setUpFrame() {     var frame = window.frames["style_file1"];    frame.runVis([{"id": "dfid", "color": "rgba(251, 230, 225, 1)", "x": -9.844811109370426, "y": -24.38053604193247, "node_shape": "dot", "border_width": 0, "title": "dfid", "degree": 3.0}, {"id": "signhealth uganda", "color": "rgba(72, 88, 104, 1)", "x": -67.55973042357344, "y": -2.0679161220645224, "node_shape": "dot", "border_width": 0, "title": "signhealth uganda", "degree": 3.0}, {"id": "kwaafrica", "color": "rgba(251, 230, 225, 1)", "x": 37.62697708859859, "y": 22.07739301768891, "node_shape": "dot", "border_width": 0, "title": "kwaafrica", "degree": 3.0}, {"id": "danida", "color": "rgba(243, 199, 102, 1)", "x": 958.2441529954832, "y": 285.6378850476516, "node_shape": "dot", "border_width": 0, "title": "danida", "degree": 3.0}, {"id": "norwegian government", "color": "rgba(243, 199, 102, 1)", "x": 377.651144372925, "y": -230.33811429343055, "node_shape": "dot", "border_width": 0, "title": "norwegian government", "degree": 3.0}, {"id": "ugu uganda christian university", "color": "rgba(72, 88, 104, 1)", "x": 392.55718494152666, "y": -267.180033500579, "node_shape": "dot", "border_width": 0, "title": "ugu uganda christian university", "degree": 3.0}, {"id": "makerere university", "color": "rgba(159, 194, 187, 1)", "x": 353.99338913989175, "y": -145.76254770295722, "node_shape": "dot", "border_width": 0, "title": "makerere university", "degree": 3.0}, {"id": "kyambogo university", "color": "rgba(243, 199, 102, 1)", "x": 400.2062590330719, "y": -259.66325203742394, "node_shape": "dot", "border_width": 0, "title": "kyambogo university", "degree": 3.0}, {"id": "ungt entreprenrskap", "color": "rgba(243, 199, 102, 1)", "x": 416.3626857916189, "y": -247.66252830929622, "node_shape": "dot", "border_width": 0, "title": "ungt entreprenrskap", "degree": 3.0}, {"id": "mubs makerere university business school", "color": "rgba(243, 199, 102, 1)", "x": 408.97998532349044, "y": -240.3038784450318, "node_shape": "dot", "border_width": 0, "title": "mubs makerere university business school", "degree": 3.0}, {"id": "uganda national association of the blind", "color": "rgba(72, 88, 104, 1)", "x": 364.1910011383776, "y": -227.34481494658633, "node_shape": "dot", "border_width": 0, "title": "uganda national association of the blind", "degree": 3.0}, {"id": "unad uganda national association of the deaf", "color": "rgba(72, 88, 104, 1)", "x": 408.10686896719506, "y": -255.15644616320188, "node_shape": "dot", "border_width": 0, "title": "unad uganda national association of the deaf", "degree": 3.0}, {"id": "sepsel south eastern priv...", "color": "rgba(243, 199, 102, 1)", "x": 375.513285755388, "y": -263.9326276539716, "node_shape": "dot", "border_width": 0, "title": "sepsel south eastern priv...", "degree": 3.0}, {"id": "uganda ministry of education and sports", "color": "rgba(72, 88, 104, 1)", "x": 385.90101382597453, "y": -258.3436505883614, "node_shape": "dot", "border_width": 0, "title": "uganda ministry of education and sports", "degree": 3.0}, {"id": "canada", "color": "rgba(243, 199, 102, 1)", "x": -355.7873117035005, "y": 623.697476785847, "node_shape": "dot", "border_width": 0, "title": "canada", "degree": 3.0}, {"id": "aucc association des univ...", "color": "rgba(243, 199, 102, 1)", "x": -373.0960235187449, "y": 626.2178949978854, "node_shape": "dot", "border_width": 0, "title": "aucc association des univ...", "degree": 3.0}, {"id": "bcei bureau canadien de lducation internationale", "color": "rgba(159, 194, 187, 1)", "x": -362.74442547765625, "y": 603.7306315052008, "node_shape": "dot", "border_width": 0, "title": "bcei bureau canadien de lducation internationale", "degree": 3.0}, {"id": "unicef", "color": "rgba(243, 199, 102, 1)", "x": -179.9724865065109, "y": -2.0431569810590515, "node_shape": "dot", "border_width": 0, "title": "unicef", "degree": 3.0}, {"id" ...
